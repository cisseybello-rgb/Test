# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# My Projet

# %% [markdown]
# Introduction

# %% [markdown]
# Python – Most popular; great for ML, data analysis, visualization.
#
# R – Strong for statistics, academic research, and data visualization.
#
# SQL – Essential for querying and managing data in databases.
#
# Julia – High-performance numerical computing and machine learning.
#
# Scala – Used with Apache Spark for big data processing.
#
# Java – Used in enterprise systems and big data frameworks (Hadoop, Spark).
#
# MATLAB – Used in engineering, simulations, and numerical analysis.
#
# SAS – Used in corporate analytics, especially finance and healthcare.

# %% [markdown]
# **BAC Project**

# %% [markdown]
# This is my first Notebook project

# %% [markdown]
# The list of data science languages
# * R
# * SQL
# * Julia
# * Scala
# * Java

# %% [markdown]
# Data science in Python relies on several powerful libraries that support analysis, visualization, and machine learning:
#
# 1. NumPy
# 2. Pandas
# 3. Matplotlib
# 4. Seaborn
# 5. Scikit-learn

# %% [markdown]
# Below is a table summarizing several widely used Data Science tools and their primary purposes:
#
# | Tool           | Category          | Primary Use                                    |
# |----------------|-------------------|------------------------------------------------|
# | Jupyter Notebook | Interactive Computing | Writing and executing code, documentation     |
# | RStudio        | IDE               | Data analysis and visualization using R        |
# | Apache Spark   | Big Data Platform | Distributed data processing                    |
# | TensorFlow     | Deep Learning     | Building and training neural networks          |
# | Tableau        | Visualization     | Creating interactive dashboards and charts     |

# %% [markdown]
# Below are a few basic arithmetic expression examples commonly used in programming and data analysis:
#
# - `2 + 3` — Addition
# - `7 - 4` — Subtraction
# - `5 * 6` — Multiplication
# - `12 / 3` — Division
# - `2 ** 3` — Exponentiation

# %%
# Simple arithmetic operations: addition and multiplication

# Add two numbers
a = 5
b = 7
sum_result = a + b

# Multiply two numbers
x = 4
y = 3
product_result = x * y

sum_result, product_result
# Out:
# (12, 12)

# %%
# Convert minutes to hours

minutes = 150
hours = minutes / 60

hours
# Out:
# 2.5

# %% [markdown]
# Below is an unordered list highlighting several key concepts in data science:
#
# - Data collection
# - Data cleaning
# - Data visualization
# - Statistical analysis
# - Machine learning

# %% [markdown]
# **Author:** Cissey
